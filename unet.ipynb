# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

# %%
def conv_block(inputs, num_filters):
  x = Conv2D(num_filters, 3, padding = 'same')(inputs)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(num_filters, 3, padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  return x

# %%
def encoder_block(inputs, num_filters):
  x = conv_block(inputs, num_filters)
  p = MaxPool2D((2,2))(x)

  return x, p

# %%
def decoder_block(inputs, skip_features, num_filters):
  x = Conv2DTranspose(num_filters, (2,2), strides = 2, padding = 'same')(inputs)
  x = Concatenate()([x, skip_features])
  x = conv_block(x, num_filters)
  
  return x

# %%
def build_unet(input_shape):
  inputs = Input(input_shape)

  """Encoder"""
  s1, p1 = encoder_block(inputs, 64)
  s2, p2 = encoder_block(p1, 128)
  s3, p3 = encoder_block(p2, 256)
  s4, p4 = encoder_block(p3, 512)

  """Bridge"""

  b1 = conv_block(p4,1024)

  """Decoder"""

  d1 = decoder_block(b1, s4, 512)
  d2 = decoder_block(d1, s3, 256)
  d3 = decoder_block(d2, s2, 128)
  d4 = decoder_block(d3, s1, 64)

  """Output"""

  outputs = Conv2D(4, (1,1), padding = 'same', activation = 'sigmoid')(d4)

  model = Model(inputs, outputs, name = 'U-Net')
  return model

# %%
input_shape = (512,512,3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_49 (Conv2D)             (None, 512, 512, 64  1792        ['input_5[0][0]']
#                                 )
#
#  batch_normalization_48 (BatchN  (None, 512, 512, 64  256        ['conv2d_49[0][0]']
#  ormalization)                  )
#
#  activation_48 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_48[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 512, 512, 64  36928       ['activation_48[0][0]']
#                                 )
#
#  batch_normalization_49 (BatchN  (None, 512, 512, 64  256        ['conv2d_50[0][0]']
#  ormalization)                  )
#
#  activation_49 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_49[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 256, 256, 64  0          ['activation_49[0][0]']
#  )                              )
#
#  conv2d_51 (Conv2D)             (None, 256, 256, 12  73856       ['max_pooling2d_12[0][0]']
#                                 8)
#
#  batch_normalization_50 (BatchN  (None, 256, 256, 12  512        ['conv2d_51[0][0]']
#  ormalization)                  8)
#
#  activation_50 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_50[0][0]']
#                                 8)
#
#  conv2d_52 (Conv2D)             (None, 256, 256, 12  147584      ['activation_50[0][0]']
#                                 8)
#
#  batch_normalization_51 (BatchN  (None, 256, 256, 12  512        ['conv2d_52[0][0]']
#  ormalization)                  8)
#
#  activation_51 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_51[0][0]']
#                                 8)
#
#  max_pooling2d_13 (MaxPooling2D  (None, 128, 128, 12  0          ['activation_51[0][0]']
#  )                              8)
#
#  conv2d_53 (Conv2D)             (None, 128, 128, 25  295168      ['max_pooling2d_13[0][0]']
#                                 6)
#
#  batch_normalization_52 (BatchN  (None, 128, 128, 25  1024       ['conv2d_53[0][0]']
#  ormalization)                  6)
#
#  activation_52 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_52[0][0]']
#                                 6)
#
#  conv2d_54 (Conv2D)             (None, 128, 128, 25  590080      ['activation_52[0][0]']
#                                 6)
#
#  batch_normalization_53 (BatchN  (None, 128, 128, 25  1024       ['conv2d_54[0][0]']
#  ormalization)                  6)
#
#  activation_53 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_53[0][0]']
#                                 6)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 64, 64, 256)  0          ['activation_53[0][0]']
#  )
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 512)  1180160     ['max_pooling2d_14[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_55[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 32, 32, 512)  0          ['activation_55[0][0]']
#  )
#
#  conv2d_57 (Conv2D)             (None, 32, 32, 1024  4719616     ['max_pooling2d_15[0][0]']
#                                 )
#
#  batch_normalization_56 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_57[0][0]']
#  ormalization)                  )
#
#  activation_56 (Activation)     (None, 32, 32, 1024  0           ['batch_normalization_56[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 32, 32, 1024  9438208     ['activation_56[0][0]']
#                                 )
#
#  batch_normalization_57 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_58[0][0]']
#  ormalization)                  )
#
#  activation_57 (Activation)     (None, 32, 32, 1024  0           ['batch_normalization_57[0][0]']
#                                 )
#
#  conv2d_transpose_9 (Conv2DTran  (None, 64, 64, 512)  2097664    ['activation_57[0][0]']
#  spose)
#
#  concatenate_9 (Concatenate)    (None, 64, 64, 1024  0           ['conv2d_transpose_9[0][0]',
#                                 )                                 'activation_55[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_9[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_59[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 128, 128, 25  524544     ['activation_59[0][0]']
#  nspose)                        6)
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 51  0           ['conv2d_transpose_10[0][0]',
#                                 2)                                'activation_53[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_10[0][0]']
#                                 6)
#
#  batch_normalization_60 (BatchN  (None, 128, 128, 25  1024       ['conv2d_61[0][0]']
#  ormalization)                  6)
#
#  activation_60 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_60[0][0]']
#                                 6)
#
#  conv2d_62 (Conv2D)             (None, 128, 128, 25  590080      ['activation_60[0][0]']
#                                 6)
#
#  batch_normalization_61 (BatchN  (None, 128, 128, 25  1024       ['conv2d_62[0][0]']
#  ormalization)                  6)
#
#  activation_61 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_61[0][0]']
#                                 6)
#
#  conv2d_transpose_11 (Conv2DTra  (None, 256, 256, 12  131200     ['activation_61[0][0]']
#  nspose)                        8)
#
#  concatenate_11 (Concatenate)   (None, 256, 256, 25  0           ['conv2d_transpose_11[0][0]',
#                                 6)                                'activation_51[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_11[0][0]']
#                                 8)
#
#  batch_normalization_62 (BatchN  (None, 256, 256, 12  512        ['conv2d_63[0][0]']
#  ormalization)                  8)
#
#  activation_62 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_62[0][0]']
#                                 8)
#
#  conv2d_64 (Conv2D)             (None, 256, 256, 12  147584      ['activation_62[0][0]']
#                                 8)
#
#  batch_normalization_63 (BatchN  (None, 256, 256, 12  512        ['conv2d_64[0][0]']
#  ormalization)                  8)
#
#  activation_63 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_63[0][0]']
#                                 8)
#
#  conv2d_transpose_12 (Conv2DTra  (None, 512, 512, 64  32832      ['activation_63[0][0]']
#  nspose)                        )
#
#  concatenate_12 (Concatenate)   (None, 512, 512, 12  0           ['conv2d_transpose_12[0][0]',
#                                 8)                                'activation_49[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_12[0][0]']
#                                 )
#
#  batch_normalization_64 (BatchN  (None, 512, 512, 64  256        ['conv2d_65[0][0]']
#  ormalization)                  )
#
#  activation_64 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_64[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 512, 512, 64  36928       ['activation_64[0][0]']
#                                 )
#
#  batch_normalization_65 (BatchN  (None, 512, 512, 64  256        ['conv2d_66[0][0]']
#  ormalization)                  )
#
#  activation_65 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_65[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 512, 512, 4)  260         ['activation_65[0][0]']
#
# ==================================================================================================
# Total params: 31,055,492
# Trainable params: 31,043,716
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
